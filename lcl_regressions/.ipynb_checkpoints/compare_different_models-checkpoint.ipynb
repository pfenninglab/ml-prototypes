# %%
import pandas as pd
import numpy as np
from scipy.stats import pearsonr, spearmanr, ttest_1samp, ttest_ind_from_stats, zscore
from scipy.special import logit
import matplotlib.pyplot as plt
from matplotlib import rcParams
rcParams.update({'figure.autolayout': True})
rcParams['svg.fonttype'] = 'none'
rcParams['font.size']=15

from seaborn import jointplot, scatterplot

from keras.models import Sequential, load_model

# %%
dnase_regression = load_model('/projects/pfenninggroup/machineLearningForComputationalBiology/eramamur_stuff/ml_lcl/model_11_hg19.hdf5', compile=False)
dnase_classifier = load_model('/projects/pfenninggroup/machineLearningForComputationalBiology/eramamur_stuff/ml_lcl/classification_model_3.hdf5', compile=False)
mpra_regression = load_model('/projects/pfenninggroup/machineLearningForComputationalBiology/eramamur_stuff/ml_lcl/tewhey_mpra_training/model_8.hdf5', compile=False)

# %%
tewhey_ref_sequences = np.load("/projects/pfenninggroup/machineLearningForComputationalBiology/eramamur_stuff/ml_lcl/tewhey_one_hot_encoded_ref_sequences.npy")
tewhey_alt_sequences = np.load("/projects/pfenninggroup/machineLearningForComputationalBiology/eramamur_stuff/ml_lcl/tewhey_one_hot_encoded_alt_sequences.npy")

# %%
tewhey_snp_info = pd.read_csv("/projects/pfenninggroup/machineLearningForComputationalBiology/eramamur_stuff/ml_lcl/tewhey_snps_data_extended_joined_to_1kg_mappings_with_1kb_snp_centered_sequences_with_gm_overlaps.txt",
                              sep="\t")

# %%
dnase_regression_ref_scores = dnase_regression.predict(tewhey_ref_sequences)
dnase_regression_alt_scores = dnase_regression.predict(tewhey_alt_sequences)

dnase_classifier_ref_scores = logit(dnase_classifier.predict_proba(tewhey_ref_sequences))
dnase_classifier_alt_scores = logit(dnase_classifier.predict_proba(tewhey_alt_sequences))

mpra_regression_ref_scores = mpra_regression.predict(tewhey_ref_sequences)
mpra_regression_alt_scores = mpra_regression.predict(tewhey_alt_sequences)

# %%
np.save("dnase_regression_ref_scores.npy", dnase_regression_ref_scores)
np.save("dnase_regression_alt_scores.npy", dnase_regression_alt_scores)
np.save("dnase_classifier_ref_scores.npy", dnase_classifier_ref_scores)
np.save("dnase_classifier_alt_scores.npy", dnase_classifier_alt_scores)
np.save("mpra_regression_ref_scores.npy", mpra_regression_ref_scores)
np.save("mpra_regression_alt_scores.npy", mpra_regression_alt_scores)

# %%
dnase_regression_ref_scores = np.load("dnase_regression_ref_scores.npy")
dnase_regression_alt_scores = np.load("dnase_regression_alt_scores.npy")
dnase_classifier_ref_scores = np.load("dnase_classifier_ref_scores.npy")
dnase_classifier_alt_scores = np.load("dnase_classifier_alt_scores.npy")
mpra_regression_ref_scores  = np.load("mpra_regression_ref_scores.npy")
mpra_regression_alt_scores  = np.load("mpra_regression_alt_scores.npy")

# %%
tewhey_snp_info["Ref.Dnase.Regression"] = dnase_regression_ref_scores
tewhey_snp_info["Alt.Dnase.Regression"] = dnase_regression_alt_scores
tewhey_snp_info["Ref.Dnase.Classifier"] = dnase_classifier_ref_scores
tewhey_snp_info["Alt.Dnase.Classifier"] = dnase_classifier_alt_scores
tewhey_snp_info["Ref.MPRA.Regression"] = mpra_regression_ref_scores
tewhey_snp_info["Alt.MPRA.Regression"] = mpra_regression_alt_scores
tewhey_snp_info["max.allele.logPadj"] = tewhey_snp_info[["C.A.logPadj", "C.B.logPadj"]].max(axis=1)

# %%
tewhey_seq_info = pd.DataFrame()

# %%
tewhey_seq_info["Dnase.Regression"] = np.concatenate((dnase_regression_ref_scores, dnase_regression_alt_scores)).flatten()
tewhey_seq_info["Dnase.Classifier"] = np.concatenate((dnase_classifier_ref_scores, dnase_classifier_alt_scores)).flatten()
tewhey_seq_info["MPRA.Regression"]  = np.concatenate((mpra_regression_ref_scores, mpra_regression_alt_scores)).flatten()
tewhey_seq_info["log2FC"] = pd.concat([tewhey_snp_info["C.A.log2FC"], tewhey_snp_info["C.B.log2FC"]]).tolist()
tewhey_seq_info["chr"] = pd.concat([tewhey_snp_info["chr"], tewhey_snp_info["chr"]]).tolist()
tewhey_seq_info["active"] = pd.concat([tewhey_snp_info["max.allele.logPadj"]> -np.log10(0.01), tewhey_snp_info["max.allele.logPadj"] > -np.log10(0.01)]).tolist()
tewhey_seq_info["Ctrl.mean"] = pd.concat([tewhey_snp_info["C.A.ctrl.mean"], tewhey_snp_info["C.B.ctrl.mean"]]).tolist()

# %%
trainChrs = [17, 11, 19, 12, 5, 22, 9, 21]
validChrs = [3, 7]
testChrs = [1, 6, 10, 4, 2, 16, 20, 15, 8, 14, 18, 13]

# %%
tewhey_seq_info["Set"] = tewhey_seq_info["chr"].isin(trainChrs)*0 + tewhey_seq_info["chr"].isin(validChrs)*1 + tewhey_seq_info["chr"].isin(testChrs)*2

# %%
#shuffling just to make sure the plotting is fine when we plot train/test/val sets
tewhey_seq_info = tewhey_seq_info.sample(frac=1)

# %%
tewhey_seq_info_train_valid = tewhey_seq_info.loc[tewhey_seq_info["Set"].isin([0,1])]

# %%
tewhey_seq_info_train_valid_active = tewhey_seq_info_train_valid.loc[tewhey_seq_info_train_valid["active"]==True]
tewhey_seq_info_train_valid_inactive = tewhey_seq_info_train_valid.loc[tewhey_seq_info_train_valid["active"]==False]

# %%
plt.figure(figsize=(6,4))
scatterplot(tewhey_seq_info_train_valid["log2FC"],
            tewhey_seq_info_train_valid["Dnase.Regression"],
            size=5,
            alpha=0.2,
            linewidth=0,
            hue=tewhey_seq_info_train_valid["active"],
            palette=['k', 'C1'],
            rasterized=True
           )


r_active = tewhey_seq_info_train_valid_active[["log2FC", "Dnase.Regression"]].corr(method="pearson")["log2FC"]["Dnase.Regression"]
rho_active = tewhey_seq_info_train_valid_active[["log2FC", "Dnase.Regression"]].corr(method="spearman")["log2FC"]["Dnase.Regression"]
r_inactive = tewhey_seq_info_train_valid_inactive[["log2FC", "Dnase.Regression"]].corr(method="pearson")["log2FC"]["Dnase.Regression"]
rho_inactive = tewhey_seq_info_train_valid_inactive[["log2FC", "Dnase.Regression"]].corr(method="spearman")["log2FC"]["Dnase.Regression"]

plt.text(4.5, 5, 
         r'$r=$'+str(round(r_active, 2)),
         horizontalalignment='left',
         size='medium',
         color='C1'
        )
plt.text(4.5, 4,
         r'$\rho=$'+str(round(rho_active, 2)),
         horizontalalignment='left',
         size='medium',
         color='C1'        )
plt.text(4.5, 3, 
         r'$r=$'+str(round(r_inactive, 2)),
         horizontalalignment='left',
         size='medium',
         color='k'        )
plt.text(4.5, 2,
         r'$\rho=$'+str(round(rho_inactive, 2)),
         horizontalalignment='left',
         size='medium',
         color='k'
        )
plt.savefig("dnase_regression_rna_over_plasmid_vs_predicted_train_and_valid.svg")

# %%
plt.close()
plt.figure(figsize=(6,4))
scatterplot(tewhey_seq_info_train_valid["log2FC"],
            tewhey_seq_info_train_valid["Dnase.Classifier"],
            size=5,
            alpha=0.2,
            linewidth=0,
            hue=tewhey_seq_info_train_valid["active"],
            palette=['k', 'C0'],
            rasterized=True
           )


r_active = tewhey_seq_info_train_valid_active[["log2FC", "Dnase.Classifier"]].corr(method="pearson")["log2FC"]["Dnase.Classifier"]
rho_active = tewhey_seq_info_train_valid_active[["log2FC", "Dnase.Classifier"]].corr(method="spearman")["log2FC"]["Dnase.Classifier"]
r_inactive = tewhey_seq_info_train_valid_inactive[["log2FC", "Dnase.Classifier"]].corr(method="pearson")["log2FC"]["Dnase.Classifier"]
rho_inactive = tewhey_seq_info_train_valid_inactive[["log2FC", "Dnase.Classifier"]].corr(method="spearman")["log2FC"]["Dnase.Classifier"]

plt.text(4.5,-12.5, 
         r'$r=$'+str(round(r_active, 2)),
         horizontalalignment='left',
         size='medium',
         color='C0'
        )
plt.text(4.5,-15,
         r'$\rho=$'+str(round(rho_active, 2)),
         horizontalalignment='left',
         size='medium',
         color='C0'        )
plt.text(4.5,-17.5, 
         r'$r=$'+str(round(r_inactive, 2)),
         horizontalalignment='left',
         size='medium',
         color='k'        )
plt.text(4.5,-20,
         r'$\rho=$'+str(round(rho_inactive, 2)),
         horizontalalignment='left',
         size='medium',
         color='k'
        )


plt.savefig("dnase_classifier_rna_over_plasmid_vs_predicted_train_and_valid.svg")

# %%
tewhey_seq_info_train = tewhey_seq_info_train_valid.loc[tewhey_seq_info_train_valid["Set"]==0]
tewhey_seq_info_valid = tewhey_seq_info_train_valid.loc[tewhey_seq_info_train_valid["Set"]==1]

# %%
tewhey_seq_info_train_valid = tewhey_seq_info_train_valid.sample(frac=1)

# %%
plt.close()
plt.figure(figsize=(6,4))
scatterplot("log2FC",
            "MPRA.Regression",
            data = tewhey_seq_info_train_valid,
            hue = "Set",
            palette = 'viridis',
            linewidth=0,
            size=5,
            alpha=0.5,
            rasterized=True
           )

r_train = tewhey_seq_info_train[["log2FC", "MPRA.Regression"]].corr(method="pearson")["log2FC"]["MPRA.Regression"]
rho_train = tewhey_seq_info_train[["log2FC", "MPRA.Regression"]].corr(method="spearman")["log2FC"]["MPRA.Regression"]
r_valid = tewhey_seq_info_valid[["log2FC", "MPRA.Regression"]].corr(method="pearson")["log2FC"]["MPRA.Regression"]
rho_valid = tewhey_seq_info_valid[["log2FC", "MPRA.Regression"]].corr(method="spearman")["log2FC"]["MPRA.Regression"]

plt.text(4.5,0.25, 
         r'$r=$'+str(round(r_train, 2)),
         horizontalalignment='left',
         size='medium',
         color='#39568cff'
        )
plt.text(4.5,0,
         r'$\rho=$'+str(round(rho_train, 2)),
         horizontalalignment='left',
         size='medium',
         color='#39568cff'
        )
plt.text(4.5,-0.25, 
         r'$r=$'+str(round(r_valid, 2)),
         horizontalalignment='left',
         size='medium',
         color='#1f968bff'
        )
plt.text(4.5,-0.5,
         r'$\rho=$'+str(round(rho_valid, 2)),
         horizontalalignment='left',
         size='medium',
         color='#1f968bff'
        )

plt.savefig("mpra_regression_rna_over_plasmid_vs_predicted_train_valid_colored.svg")

# %%
plt.close()
plt.figure(figsize=(6,4))
scatterplot("log2FC",
            "MPRA.Regression",
            data = tewhey_seq_info_train_valid,
            hue = "active",
            palette = ['k', 'C2'],
            linewidth=0,
            size=5,
            alpha=0.5,
            rasterized=True
           )


r_active = tewhey_seq_info_train_valid_active[["log2FC", "MPRA.Regression"]].corr(method="pearson")["log2FC"]["MPRA.Regression"]
rho_active = tewhey_seq_info_train_valid_active[["log2FC", "MPRA.Regression"]].corr(method="spearman")["log2FC"]["MPRA.Regression"]
r_inactive = tewhey_seq_info_train_valid_inactive[["log2FC", "MPRA.Regression"]].corr(method="pearson")["log2FC"]["MPRA.Regression"]
rho_inactive = tewhey_seq_info_train_valid_inactive[["log2FC", "MPRA.Regression"]].corr(method="spearman")["log2FC"]["MPRA.Regression"]

plt.text(4.5,0.5, 
         r'$r=$'+str(round(r_active, 2)),
         horizontalalignment='left',
         size='medium',
         color='C2'
        )
plt.text(4.5,0.25,
         r'$\rho=$'+str(round(rho_active, 2)),
         horizontalalignment='left',
         size='medium',
         color='C2'        )
plt.text(4.5,-0, 
         r'$r=$'+str(round(r_inactive, 2)),
         horizontalalignment='left',
         size='medium',
         color='k'        )
plt.text(4.5,-0.25,
         r'$\rho=$'+str(round(rho_inactive, 2)),
         horizontalalignment='left',
         size='medium',
         color='k'
        )


plt.savefig("mpra_regression_rna_over_plasmid_vs_predicted_train_and_valid.svg")

# %%
tewhey_seq_info_train_active = tewhey_seq_info_train_valid_active.loc[tewhey_seq_info_train_valid_active["Set"]==0]
tewhey_seq_info_valid_active = tewhey_seq_info_train_valid_active.loc[tewhey_seq_info_train_valid_active["Set"]==1]

# %%
plt.close()
plt.figure(figsize=(6,4))

scatterplot("log2FC",
            "MPRA.Regression",
            data = tewhey_seq_info_train_valid_active,
            hue = "Set",
            palette = "viridis",
            size=5,
            linewidth=0,
            alpha=0.5,
            rasterized=True
           )



r_train = tewhey_seq_info_train_active[["log2FC", "MPRA.Regression"]].corr(method="pearson")["log2FC"]["MPRA.Regression"]
rho_train = tewhey_seq_info_train_active[["log2FC", "MPRA.Regression"]].corr(method="spearman")["log2FC"]["MPRA.Regression"]
r_valid = tewhey_seq_info_valid_active[["log2FC", "MPRA.Regression"]].corr(method="pearson")["log2FC"]["MPRA.Regression"]
rho_valid = tewhey_seq_info_valid_active[["log2FC", "MPRA.Regression"]].corr(method="spearman")["log2FC"]["MPRA.Regression"]

plt.text(4.5,0.25, 
         r'$r=$'+str(round(r_train, 2)),
         horizontalalignment='left',
         size='medium',
         color='#39568cff'
        )
plt.text(4.5,0,
         r'$\rho=$'+str(round(rho_train, 2)),
         horizontalalignment='left',
         size='medium',
         color='#39568cff'
        )
plt.text(4.5,-0.25, 
         r'$r=$'+str(round(r_valid, 2)),
         horizontalalignment='left',
         size='medium',
         color='#1f968bff'
        )
plt.text(4.5,-0.5,
         r'$\rho=$'+str(round(rho_valid, 2)),
         horizontalalignment='left',
         size='medium',
         color='#1f968bff'
        )



plt.savefig("mpra_regression_rna_over_plasmid_vs_predicted_only_active_train_valid_colored.svg")

# %%
print(tewhey_seq_info_train_valid.drop(["chr", "Set"], axis=1).corr(method="pearson"))
print(tewhey_seq_info_train_valid.drop(["chr", "Set"], axis=1).corr(method="spearman"))
# Out:
#                   Dnase.Regression  Dnase.Classifier  MPRA.Regression  \
# Dnase.Regression          1.000000          0.405426         0.246931
# Dnase.Classifier          0.405426          1.000000         0.382842
# MPRA.Regression           0.246931          0.382842         1.000000
# log2FC                    0.237542          0.251711         0.686469
# active                    0.215863          0.229895         0.506947
# Ctrl.mean                 0.158535          0.278392         0.200940
#
#                     log2FC    active  Ctrl.mean
# Dnase.Regression  0.237542  0.215863   0.158535
# Dnase.Classifier  0.251711  0.229895   0.278392
# MPRA.Regression   0.686469  0.506947   0.200940
# log2FC            1.000000  0.627836   0.083523
# active            0.627836  1.000000   0.187778
# Ctrl.mean         0.083523  0.187778   1.000000
#                   Dnase.Regression  Dnase.Classifier  MPRA.Regression  \
# ...

# %%
print(tewhey_seq_info_train_valid.loc[tewhey_seq_info_train_valid["Set"]==0][["log2FC", "MPRA.Regression"]].corr(method="pearson"))
print(tewhey_seq_info_train_valid.loc[tewhey_seq_info_train_valid["Set"]==0][["log2FC", "MPRA.Regression"]].corr(method="spearman"))
# Out:
#                    log2FC  MPRA.Regression
# log2FC           1.000000         0.727699
# MPRA.Regression  0.727699         1.000000
#                    log2FC  MPRA.Regression
# log2FC           1.000000         0.596338
# MPRA.Regression  0.596338         1.000000

# %%
print(tewhey_seq_info_train_valid.loc[tewhey_seq_info_train_valid["Set"]==1][["log2FC", "MPRA.Regression"]].corr(method="pearson"))
print(tewhey_seq_info_train_valid.loc[tewhey_seq_info_train_valid["Set"]==1][["log2FC", "MPRA.Regression"]].corr(method="spearman"))
# Out:
#                    log2FC  MPRA.Regression
# log2FC           1.000000         0.434389
# MPRA.Regression  0.434389         1.000000
#                    log2FC  MPRA.Regression
# log2FC           1.000000         0.316751
# MPRA.Regression  0.316751         1.000000

# %%
tewhey_snp_info["DNase.Regression.Skew"] = tewhey_snp_info["Alt.Dnase.Regression"] - tewhey_snp_info["Ref.Dnase.Regression"]
tewhey_snp_info["DNase.Classifier.Skew"] = tewhey_snp_info["Alt.Dnase.Classifier"] - tewhey_snp_info["Ref.Dnase.Classifier"]
tewhey_snp_info["MPRA.Regression.Skew"] = tewhey_snp_info["Alt.MPRA.Regression"] - tewhey_snp_info["Ref.MPRA.Regression"]

# %%
tewhey_snp_info.columns
# Out:
# Index(['ID', 'SNP', 'Direction', 'Haplotype', 'C.A.ctrl.mean', 'C.A.exp.mean',
#        'C.A.log2FC', 'C.A.logP', 'C.A.logPadj', 'C.B.ctrl.mean',
#        'C.B.exp.mean', 'C.B.log2FC', 'C.B.logP', 'C.B.logPadj',
#        'LogSkew.12878', 'LogSkew.19239', 'LogSkew.Comb', 'C.Skew.logP',
#        'C.Skew.fdr', 'tewhey_id', 'chr', '1kg_mapped_id', 'pos', 'hg19_alt',
#        'hg19_ref', 'REF.sequence.1kb', 'ALT.sequence.1kb',
#        'Num.Overlaps.GM.peaks', 'Ref.Dnase.Regression', 'Alt.Dnase.Regression',
#        'Ref.Dnase.Classifier', 'Alt.Dnase.Classifier', 'Ref.MPRA.Regression',
#        'Alt.MPRA.Regression', 'max.allele.logPadj', 'DNase.Regression.Skew',
#        'DNase.Classifier.Skew', 'MPRA.Regression.Skew'],
#       dtype='object')

# %%
tewhey_snp_info_train_valid = tewhey_snp_info.loc[~tewhey_snp_info["chr"].isin(testChrs)]

# %%
tewhey_snp_info_train_valid.shape
# Out:
# (22811, 38)

# %%
scatterplot(tewhey_snp_info_train_valid["DNase.Classifier.Skew"], tewhey_snp_info_train_valid["DNase.Regression.Skew"], hue=tewhey_snp_info_train_valid["C.Skew.fdr"] > -np.log10(0.01), palette = ['white', 'r'], alpha=0.5,size=5,linewidth=0)
plt.axhline(c='k', linestyle='--')
plt.axvline(c='k', linestyle='--')
plt.show()

# %%
scatterplot(tewhey_snp_info_train_valid["MPRA.Regression.Skew"], tewhey_snp_info_train_valid["DNase.Regression.Skew"], hue=tewhey_snp_info_train_valid["C.Skew.fdr"] > -np.log10(0.01), palette = ['white', 'r'], alpha=0.5,size=5,linewidth=0)
plt.axhline(c='k', linestyle='--')
plt.axvline(c='k', linestyle='--')
plt.show()

# %%
scatterplot(tewhey_snp_info_train_valid["MPRA.Regression.Skew"], tewhey_snp_info_train_valid["DNase.Classifier.Skew"], hue=tewhey_snp_info_train_valid["C.Skew.fdr"] > -np.log10(0.01), palette = ['white', 'r'], alpha=0.5,size=5,linewidth=0)
plt.axhline(c='k', linestyle='--')
plt.axvline(c='k', linestyle='--')
plt.show()

# %%
scatterplot(tewhey_snp_info_train_valid["LogSkew.Comb"], tewhey_snp_info_train_valid["DNase.Regression.Skew"], hue=tewhey_snp_info_train_valid["C.Skew.fdr"] > -np.log10(0.01), palette = ['k', 'r'], alpha=0.5,size=5,linewidth=0)
plt.axhline(c='k', linestyle='--')
plt.axvline(c='k', linestyle='--')
plt.show()

# %%
scatterplot(tewhey_snp_info_train_valid["LogSkew.Comb"], tewhey_snp_info_train_valid["DNase.Classifier.Skew"], hue=tewhey_snp_info_train_valid["C.Skew.fdr"] > -np.log10(0.01), palette = ['k', 'r'], alpha=0.5,size=5,linewidth=0)
plt.axhline(c='k', linestyle='--')
plt.axvline(c='k', linestyle='--')
plt.show()

# %%
scatterplot(tewhey_snp_info_train_valid["LogSkew.Comb"], tewhey_snp_info_train_valid["MPRA.Regression.Skew"], hue=tewhey_snp_info_train_valid["C.Skew.fdr"] > -np.log10(0.01), palette = ['k', 'r'], alpha=0.5,size=5,linewidth=0)
plt.axhline(c='k')
plt.axvline(c='k')
plt.show()

# %%
tewhey_snp_info_train_valid_active = tewhey_snp_info_train_valid.loc[tewhey_snp_info_train_valid["max.allele.logPadj"] > -np.log10(0.01)]

# %%
tewhey_snp_info_train_valid_pos = tewhey_snp_info_train_valid_active[(tewhey_snp_info_train_valid_active["C.Skew.fdr"] > -np.log10(0.01)) & (tewhey_snp_info_train_valid_active["LogSkew.Comb"]>0)]
tewhey_snp_info_train_valid_neg = tewhey_snp_info_train_valid_active[(tewhey_snp_info_train_valid_active["C.Skew.fdr"] > -np.log10(0.01)) & (tewhey_snp_info_train_valid_active["LogSkew.Comb"]<0)]
tewhey_snp_info_train_valid_neutral = tewhey_snp_info_train_valid_active[(tewhey_snp_info_train_valid_active["C.Skew.fdr"] < -np.log10(0.01)) & (np.absolute(tewhey_snp_info_train_valid_active["LogSkew.Comb"])<0.2)]

# %%
def z_with_center(values, center = 0):
    return (values-center)/np.std(values)

# %%
plottables =[z_with_center(tewhey_snp_info_train_valid_neg["DNase.Classifier.Skew"].dropna()).tolist(),
             z_with_center(tewhey_snp_info_train_valid_neg["DNase.Regression.Skew"].dropna()).tolist(),
             z_with_center(tewhey_snp_info_train_valid_neg["MPRA.Regression.Skew"].dropna()).tolist(),
             z_with_center(tewhey_snp_info_train_valid_neutral["DNase.Classifier.Skew"].dropna()).tolist(),
             z_with_center(tewhey_snp_info_train_valid_neutral["DNase.Regression.Skew"].dropna()).tolist(),
             z_with_center(tewhey_snp_info_train_valid_neutral["MPRA.Regression.Skew"].dropna()).tolist(),             
             z_with_center(tewhey_snp_info_train_valid_pos["DNase.Classifier.Skew"].dropna()).tolist(),
             z_with_center(tewhey_snp_info_train_valid_pos["DNase.Regression.Skew"].dropna()).tolist(),
             z_with_center(tewhey_snp_info_train_valid_pos["MPRA.Regression.Skew"].dropna()).tolist()]

# %%
print(ttest_1samp(tewhey_snp_info_train_valid_neg["DNase.Classifier.Skew"].dropna().tolist(),0))
print(ttest_1samp(tewhey_snp_info_train_valid_neutral["DNase.Classifier.Skew"].dropna().tolist(),0))
print(ttest_1samp(tewhey_snp_info_train_valid_pos["DNase.Classifier.Skew"].dropna().tolist(),0))
print(ttest_ind_from_stats(np.mean(tewhey_snp_info_train_valid_neg["DNase.Classifier.Skew"].dropna()),
                     np.std(tewhey_snp_info_train_valid_neg["DNase.Classifier.Skew"].dropna()),
                     len(tewhey_snp_info_train_valid_neg["DNase.Classifier.Skew"].dropna().tolist()),
                     np.mean(tewhey_snp_info_train_valid_neutral["DNase.Classifier.Skew"].dropna()),
                     np.std(tewhey_snp_info_train_valid_neutral["DNase.Classifier.Skew"].dropna()),
                     len(tewhey_snp_info_train_valid_neutral["DNase.Classifier.Skew"].dropna().tolist()),
                     equal_var=False))
print(ttest_ind_from_stats(np.mean(tewhey_snp_info_train_valid_pos["DNase.Classifier.Skew"].dropna()),
                     np.std(tewhey_snp_info_train_valid_pos["DNase.Classifier.Skew"].dropna()),
                     len(tewhey_snp_info_train_valid_pos["DNase.Classifier.Skew"].dropna().tolist()),
                     np.mean(tewhey_snp_info_train_valid_neutral["DNase.Classifier.Skew"].dropna()),
                     np.std(tewhey_snp_info_train_valid_neutral["DNase.Classifier.Skew"].dropna()),
                     len(tewhey_snp_info_train_valid_neutral["DNase.Classifier.Skew"].dropna().tolist()),
                     equal_var=False))
# Out:
# Ttest_1sampResult(statistic=-5.115380606284796, pvalue=1.2018437286587283e-06)
# Ttest_1sampResult(statistic=1.2172440194959329, pvalue=0.22370729209016432)
# Ttest_1sampResult(statistic=5.531343640878773, pvalue=2.170466440738004e-07)
# Ttest_indResult(statistic=-5.264001057842602, pvalue=5.879522507530511e-07)
# Ttest_indResult(statistic=5.242297430408421, pvalue=7.073743115617583e-07)

# %%
print(ttest_1samp(tewhey_snp_info_train_valid_neg["DNase.Regression.Skew"].dropna().tolist(),0))
print(ttest_1samp(tewhey_snp_info_train_valid_neutral["DNase.Regression.Skew"].dropna().tolist(),0))
print(ttest_1samp(tewhey_snp_info_train_valid_pos["DNase.Regression.Skew"].dropna().tolist(),0))
print(ttest_ind_from_stats(np.mean(tewhey_snp_info_train_valid_neg["DNase.Regression.Skew"].dropna()),
                     np.std(tewhey_snp_info_train_valid_neg["DNase.Regression.Skew"].dropna()),
                     len(tewhey_snp_info_train_valid_neg["DNase.Regression.Skew"].dropna().tolist()),
                     np.mean(tewhey_snp_info_train_valid_neutral["DNase.Regression.Skew"].dropna()),
                     np.std(tewhey_snp_info_train_valid_neutral["DNase.Regression.Skew"].dropna()),
                     len(tewhey_snp_info_train_valid_neutral["DNase.Regression.Skew"].dropna().tolist()),
                     equal_var=False))
print(ttest_ind_from_stats(np.mean(tewhey_snp_info_train_valid_pos["DNase.Regression.Skew"].dropna()),
                     np.std(tewhey_snp_info_train_valid_pos["DNase.Regression.Skew"].dropna()),
                     len(tewhey_snp_info_train_valid_pos["DNase.Regression.Skew"].dropna().tolist()),
                     np.mean(tewhey_snp_info_train_valid_neutral["DNase.Regression.Skew"].dropna()),
                     np.std(tewhey_snp_info_train_valid_neutral["DNase.Regression.Skew"].dropna()),
                     len(tewhey_snp_info_train_valid_neutral["DNase.Regression.Skew"].dropna().tolist()),
                     equal_var=False))
# Out:
# Ttest_1sampResult(statistic=-5.374831573134598, pvalue=3.827760949129447e-07)
# Ttest_1sampResult(statistic=0.417289614817571, pvalue=0.6765275180847303)
# Ttest_1sampResult(statistic=6.010913683662428, pvalue=2.4453212480637367e-08)
# Ttest_indResult(statistic=-5.408814896749414, pvalue=3.160655054899559e-07)
# Ttest_indResult(statistic=5.928162280036518, pvalue=3.333652796857491e-08)

# %%
print(ttest_1samp(tewhey_snp_info_train_valid_neg["MPRA.Regression.Skew"].dropna().tolist(),0))
print(ttest_1samp(tewhey_snp_info_train_valid_neutral["MPRA.Regression.Skew"].dropna().tolist(),0))
print(ttest_1samp(tewhey_snp_info_train_valid_pos["MPRA.Regression.Skew"].dropna().tolist(),0))
print(ttest_ind_from_stats(np.mean(tewhey_snp_info_train_valid_neg["MPRA.Regression.Skew"].dropna()),
                     np.std(tewhey_snp_info_train_valid_neg["MPRA.Regression.Skew"].dropna()),
                     len(tewhey_snp_info_train_valid_neg["MPRA.Regression.Skew"].dropna().tolist()),
                     np.mean(tewhey_snp_info_train_valid_neutral["MPRA.Regression.Skew"].dropna()),
                     np.std(tewhey_snp_info_train_valid_neutral["MPRA.Regression.Skew"].dropna()),
                     len(tewhey_snp_info_train_valid_neutral["MPRA.Regression.Skew"].dropna().tolist()),
                     equal_var=False))
print(ttest_ind_from_stats(np.mean(tewhey_snp_info_train_valid_pos["MPRA.Regression.Skew"].dropna()),
                     np.std(tewhey_snp_info_train_valid_pos["MPRA.Regression.Skew"].dropna()),
                     len(tewhey_snp_info_train_valid_pos["MPRA.Regression.Skew"].dropna().tolist()),
                     np.mean(tewhey_snp_info_train_valid_neutral["MPRA.Regression.Skew"].dropna()),
                     np.std(tewhey_snp_info_train_valid_neutral["MPRA.Regression.Skew"].dropna()),
                     len(tewhey_snp_info_train_valid_neutral["MPRA.Regression.Skew"].dropna().tolist()),
                     equal_var=False))
# Out:
# Ttest_1sampResult(statistic=-5.647687353592432, pvalue=1.1114103631861494e-07)
# Ttest_1sampResult(statistic=-1.3483290012292184, pvalue=0.17776029542499483)
# Ttest_1sampResult(statistic=6.106654875112452, pvalue=1.5654186173138063e-08)
# Ttest_indResult(statistic=-5.277673224659656, pvalue=5.295776439459847e-07)
# Ttest_indResult(statistic=6.279040358106497, pvalue=5.818811149192993e-09)

# %%
print(ttest_ind_from_stats(np.mean(tewhey_snp_info_train_valid_neg["DNase.Classifier.Skew"].dropna()),
                     np.std(tewhey_snp_info_train_valid_neg["DNase.Classifier.Skew"].dropna()),
                     len(tewhey_snp_info_train_valid_neg["DNase.Classifier.Skew"].dropna().tolist()),
                     np.mean(tewhey_snp_info_train_valid_neg["DNase.Regression.Skew"].dropna()),
                     np.std(tewhey_snp_info_train_valid_neg["DNase.Regression.Skew"].dropna()),
                     len(tewhey_snp_info_train_valid_neg["DNase.Regression.Skew"].dropna().tolist()),
                     equal_var=False))

print(np.mean(tewhey_snp_info_train_valid_neg["DNase.Classifier.Skew"].dropna()))
print(np.mean(tewhey_snp_info_train_valid_neg["DNase.Regression.Skew"].dropna()))
# Out:
# Ttest_indResult(statistic=-1.2564782297515484, pvalue=0.21033916508482853)
# -0.37484995
# -0.26441184

# %%
print(ttest_ind_from_stats(np.mean(tewhey_snp_info_train_valid_pos["DNase.Classifier.Skew"].dropna()),
                     np.std(tewhey_snp_info_train_valid_pos["DNase.Classifier.Skew"].dropna()),
                     len(tewhey_snp_info_train_valid_pos["DNase.Classifier.Skew"].dropna().tolist()),
                     np.mean(tewhey_snp_info_train_valid_pos["DNase.Regression.Skew"].dropna()),
                     np.std(tewhey_snp_info_train_valid_pos["DNase.Regression.Skew"].dropna()),
                     len(tewhey_snp_info_train_valid_pos["DNase.Regression.Skew"].dropna().tolist()),
                     equal_var=False))
print(np.mean(tewhey_snp_info_train_valid_pos["DNase.Classifier.Skew"].dropna()))
print(np.mean(tewhey_snp_info_train_valid_pos["DNase.Regression.Skew"].dropna()))
# Out:
# Ttest_indResult(statistic=1.160062468520733, pvalue=0.24744219882300353)
# 0.3478303
# 0.25972027

# %%
fig, ax = plt.subplots(figsize=(8,8))

parts = ax.violinplot(dataset=plottables,
                               showmedians=False,showextrema=False)

for i in range(0,9,3):
    parts['bodies'][i].set_facecolor('C0')
    parts['bodies'][i].set_edgecolor('black')
    parts['bodies'][i].set_alpha(1)
for i in range(1,9,3):   
    parts['bodies'][i].set_facecolor('C1')
    parts['bodies'][i].set_edgecolor('black')
    parts['bodies'][i].set_alpha(1)    
for i in range(2,9,3):
    parts['bodies'][i].set_facecolor('C2')
    parts['bodies'][i].set_edgecolor('black')
    parts['bodies'][i].set_alpha(1)   

plt.boxplot(plottables)


plt.axhline(y=0, c='k', linestyle='--')
plt.xticks(ticks = range(2,9,3), labels = ["Skew Negative emVAR\n(q<0.01)", "Neutral\n(-0.2<Log.Skew<0.2,\nq>0.01)", "Skew Positive emVAR\n(q<0.01)"], horizontalalignment="center")
plt.ylabel("Predicted.Skew\nlog2(alt/ref)")
plt.savefig("compare_models_q_0.01_emVAR_violin.svg")
#print(ttest_1samp(train_tewhey_snp_info_neg["Predicted.skew"].tolist(),0))
#print(ttest_1samp(train_tewhey_snp_info_neutral["Predicted.skew"].tolist(),0))
#print(ttest_1samp(train_tewhey_snp_info_pos["Predicted.skew"].tolist(),0))
#print(ttest_ind_from_stats(np.mean(train_tewhey_snp_info_neg["Predicted.skew"]),
#                     np.std(train_tewhey_snp_info_neg["Predicted.skew"]),
#                     len(train_tewhey_snp_info_neg["Predicted.skew"].tolist()),
#                     np.mean(train_tewhey_snp_info_neutral["Predicted.skew"]),
#                     np.std(train_tewhey_snp_info_neutral["Predicted.skew"]),
#                     len(train_tewhey_snp_info_neutral["Predicted.skew"].tolist()),
#                     equal_var=False))
#print(ttest_ind_from_stats(np.mean(train_tewhey_snp_info_pos["Predicted.skew"]),
#                    np.std(train_tewhey_snp_info_pos["Predicted.skew"]),
#                    len(train_tewhey_snp_info_pos["Predicted.skew"].tolist()),
#                    np.mean(train_tewhey_snp_info_neutral["Predicted.skew"]),
#                    np.std(train_tewhey_snp_info_neutral["Predicted.skew"]),
#                    len(train_tewhey_snp_info_neutral["Predicted.skew"].tolist()),
#                    equal_var=False))

# %%
print((tewhey_snp_info_train_valid_pos.loc[tewhey_snp_info_train_valid_pos["DNase.Classifier.Skew"]>0]).shape)
print((tewhey_snp_info_train_valid_neg.loc[tewhey_snp_info_train_valid_neg["DNase.Classifier.Skew"]<0]).shape)

print((tewhey_snp_info_train_valid_pos.loc[tewhey_snp_info_train_valid_pos["DNase.Regression.Skew"]>0]).shape)
print((tewhey_snp_info_train_valid_neg.loc[tewhey_snp_info_train_valid_neg["DNase.Regression.Skew"]<0]).shape)

print((tewhey_snp_info_train_valid_pos.loc[tewhey_snp_info_train_valid_pos["MPRA.Regression.Skew"]>0]).shape)
print((tewhey_snp_info_train_valid_neg.loc[tewhey_snp_info_train_valid_neg["MPRA.Regression.Skew"]<0]).shape)
# Out:
# (76, 38)
# (84, 38)
# (75, 38)
# (87, 38)
# (81, 38)
# (90, 38)

# %%
dnase_regression_accuracies = []
dnase_classifier_accuracies = []
mpra_regression_accuracies = []
naive_accuracies = []
q_cutoffs = np.logspace(-3.5,-1,50)

for q_cutoff in q_cutoffs:
    tewhey_snp_info_train_valid_pos = tewhey_snp_info_train_valid_active[(tewhey_snp_info_train_valid_active["C.Skew.fdr"] > -np.log10(q_cutoff)) & (tewhey_snp_info_train_valid_active["LogSkew.Comb"]>0)]
    tewhey_snp_info_train_valid_neg = tewhey_snp_info_train_valid_active[(tewhey_snp_info_train_valid_active["C.Skew.fdr"] > -np.log10(q_cutoff)) & (tewhey_snp_info_train_valid_active["LogSkew.Comb"]<0)]
    tewhey_snp_info_train_valid_neutral = tewhey_snp_info_train_valid_active[(tewhey_snp_info_train_valid_active["C.Skew.fdr"] < -np.log10(q_cutoff)) & (np.absolute(tewhey_snp_info_train_valid_active["LogSkew.Comb"])<0.2)]
    
    dnase_classifier_train_valid_pos_accurate = (tewhey_snp_info_train_valid_pos.loc[tewhey_snp_info_train_valid_pos["DNase.Classifier.Skew"]>0]).shape[0]
    dnase_classifier_train_valid_neg_accurate = (tewhey_snp_info_train_valid_neg.loc[tewhey_snp_info_train_valid_neg["DNase.Classifier.Skew"]<0]).shape[0]
    
    dnase_regression_train_valid_pos_accurate = (tewhey_snp_info_train_valid_pos.loc[tewhey_snp_info_train_valid_pos["DNase.Regression.Skew"]>0]).shape[0]
    dnase_regression_train_valid_neg_accurate = (tewhey_snp_info_train_valid_neg.loc[tewhey_snp_info_train_valid_neg["DNase.Regression.Skew"]<0]).shape[0]

    mpra_regression_train_valid_pos_accurate = (tewhey_snp_info_train_valid_pos.loc[tewhey_snp_info_train_valid_pos["MPRA.Regression.Skew"]>0]).shape[0]
    mpra_regression_train_valid_neg_accurate = (tewhey_snp_info_train_valid_neg.loc[tewhey_snp_info_train_valid_neg["MPRA.Regression.Skew"]<0]).shape[0]

    
    total = tewhey_snp_info_train_valid_pos.shape[0] + tewhey_snp_info_train_valid_neg.shape[0]
    print(q_cutoff,tewhey_snp_info_train_valid_pos.shape[0], tewhey_snp_info_train_valid_neg.shape[0], total)
    
    dnase_classifier_train_valid_accuracy = 1.0*(dnase_classifier_train_valid_pos_accurate+dnase_classifier_train_valid_neg_accurate)/total
    dnase_regression_train_valid_accuracy = 1.0*(dnase_regression_train_valid_pos_accurate+dnase_regression_train_valid_neg_accurate)/total
    mpra_regression_train_valid_accuracy = 1.0*(mpra_regression_train_valid_pos_accurate+mpra_regression_train_valid_neg_accurate)/total
    naive_train_valid_accuracy = 1.0*max(tewhey_snp_info_train_valid_pos.shape[0], tewhey_snp_info_train_valid_neg.shape[0])/total
    
    dnase_classifier_accuracies.append(dnase_classifier_train_valid_accuracy)
    dnase_regression_accuracies.append(dnase_regression_train_valid_accuracy)
    mpra_regression_accuracies.append(mpra_regression_train_valid_accuracy)
    naive_accuracies.append(naive_train_valid_accuracy)
# Out:
# 0.00031622776601683794 13 11 24
# 0.00035564803062231287 15 11 26
# 0.0003999823395608933 17 13 30
# 0.0004498432668969444 17 14 31
# 0.0005059197488435823 22 18 40
# 0.0005689866029018299 23 21 44
# 0.0006399152336349266 23 21 44
# 0.0007196856730011522 25 22 47
# 0.0008094001216083124 26 22 48
# 0.0009102981779915217 28 25 53
# 0.0010237739663395847 33 27 60
# 0.0011513953993264481 35 28 63
# 0.0012949258422052632 41 33 74
# 0.0014563484775012444 41 36 77
# 0.0016378937069540646 44 37 81
# 0.0018420699693267163 44 41 85
# 0.0020716983998953077 49 44 93
# 0.002329951810515372 51 46 97
# 0.0026203985288583485 59 52 111
# 0.0029470517025518097 63 58 121
# 0.003314424749466425 66 61 127
# 0.003727593720314938 69 64 133
# 0.004192267435236918 72 65 137
# 0.004714866363457394 75 70 145
# 0.005302611335911987 79 81 160
# 0.005963623316594642 88 90 178
# 0.006707035611184306 91 95 186
# 0.007543120063354623 94 98 192
# 0.008483428982440725 104 114 218
# 0.009540954763499945 108 121 229
# ...

# %%
plt.plot(q_cutoffs, dnase_classifier_accuracies, c='C0', label = 'DNase classifier')
plt.plot(q_cutoffs, dnase_regression_accuracies, c='C1', label = 'DNase regression')
plt.plot(q_cutoffs, mpra_regression_accuracies, c='C2', label = 'MPRA regression')
plt.plot(q_cutoffs, naive_accuracies, c='C3', label = 'Majority Direction')
plt.xlabel("FDR q-value cutoff to define emVAR")
plt.ylabel("Accuracy of prediction of direction of emVAR affect")
plt.xscale("log")
plt.legend()
plt.savefig("compare_models_different_q_cutoffs_emvar_train_valid.svg")

# %%
scatterplot(tewhey_snp_info_train_valid[["C.A.log2FC", "C.B.log2FC"]].max(axis=1), tewhey_snp_info_train_valid["LogSkew.Comb"], hue = (tewhey_snp_info_train_valid["C.Skew.fdr"] > -np.log10(0.01)), linewidth=0, palette = ['k', 'r'], alpha=0.5, size=5)

plt.axhline(c='k', linestyle='--')
plt.axvline(c='k', linestyle='--')
plt.xlabel("log2FC")
plt.ylim([-4,4])
plt.savefig("tewhey_rna_over_plasmid_vs_skew_train_valid.svg")

# %%
scatterplot(tewhey_seq_info_train_valid["Ctrl.mean"], tewhey_seq_info_train_valid["log2FC"], hue = tewhey_seq_info_train_valid["active"], linewidth=0, palette = ['k', 'C0'], alpha=0.5, size=5)
plt.ylim([-5,7.5])
plt.xscale("log")
plt.xlim([1,1e4])
plt.axhline(c='k', linestyle='--')
plt.savefig("tewhey_plasmid_vs_rna_over_plasmid_train_valid.svg")

# %%
allele_freqs_file="/home/eramamur/resources/haploreg_v4.0_20151021_allele_freqs.txt"

# %%
allele_freqs = pd.read_csv(allele_freqs_file, sep='\t')

# %%
tewhey_snp_info_train_valid_with_allele_freqs = tewhey_snp_info_train_valid.merge(allele_freqs,
                      how='inner',
                      left_on="1kg_mapped_id",
                      right_on="RSID",
                      suffixes=('_1', '_2')
                     )

# %%
tewhey_snp_info_train_valid.shape
# Out:
# (22811, 38)

# %%
tewhey_snp_info_train_valid_with_allele_freqs.shape
# Out:
# (15271, 43)

# %%
plt.hist(tewhey_snp_info_train_valid_with_allele_freqs["EUR"],
        bins=20)
plt.xscale("log")

# %%
plt.hist(tewhey_snp_info_train_valid_with_allele_freqs["AFR"],
        bins=20)
plt.xscale("log")
# Out:
# /home/eramamur/bin/miniconda3/envs/gpu_keras_theano/lib/python3.6/site-packages/matplotlib/figure.py:2366: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "

# %%
tewhey_snp_info_train_valid_with_allele_freqs.columns
# Out:
# Index(['ID', 'SNP', 'Direction', 'Haplotype', 'C.A.ctrl.mean', 'C.A.exp.mean',
#        'C.A.log2FC', 'C.A.logP', 'C.A.logPadj', 'C.B.ctrl.mean',
#        'C.B.exp.mean', 'C.B.log2FC', 'C.B.logP', 'C.B.logPadj',
#        'LogSkew.12878', 'LogSkew.19239', 'LogSkew.Comb', 'C.Skew.logP',
#        'C.Skew.fdr', 'tewhey_id', 'chr', '1kg_mapped_id', 'pos', 'hg19_alt',
#        'hg19_ref', 'REF.sequence.1kb', 'ALT.sequence.1kb',
#        'Num.Overlaps.GM.peaks', 'Ref.Dnase.Regression', 'Alt.Dnase.Regression',
#        'Ref.Dnase.Classifier', 'Alt.Dnase.Classifier', 'Ref.MPRA.Regression',
#        'Alt.MPRA.Regression', 'max.allele.logPadj', 'DNase.Regression.Skew',
#        'DNase.Classifier.Skew', 'MPRA.Regression.Skew', 'RSID', 'AFR', 'AMR',
#        'ASN', 'EUR'],
#       dtype='object')

# %%
rare_tewhey_snp_info_train_valid_with_allele_freqs = tewhey_snp_info_train_valid_with_allele_freqs.loc[tewhey_snp_info_train_valid_with_allele_freqs["EUR"]<0.01]

lowfreq_tewhey_snp_info_train_valid_with_allele_freqs = tewhey_snp_info_train_valid_with_allele_freqs.loc[tewhey_snp_info_train_valid_with_allele_freqs["EUR"]>=0.01]
lowfreq_tewhey_snp_info_train_valid_with_allele_freqs = lowfreq_tewhey_snp_info_train_valid_with_allele_freqs.loc[lowfreq_tewhey_snp_info_train_valid_with_allele_freqs["EUR"]>=0.01]

common_tewhey_snp_info_train_valid_with_allele_freqs = tewhey_snp_info_train_valid_with_allele_freqs.loc[tewhey_snp_info_train_valid_with_allele_freqs["EUR"]>=0.05]

# %%
rare_tewhey_snp_info_train_valid_with_allele_freqs.shape
# Out:
# (1707, 43)

# %%
lowfreq_tewhey_snp_info_train_valid_with_allele_freqs.shape
# Out:
# (13564, 43)

# %%
common_tewhey_snp_info_train_valid_with_allele_freqs.shape
# Out:
# (13183, 43)

# %%
rare_tewhey_snp_info_train_valid_with_allele_freqs_sig = rare_tewhey_snp_info_train_valid_with_allele_freqs.loc[rare_tewhey_snp_info_train_valid_with_allele_freqs["C.Skew.fdr"]>-np.log10(0.001)]

lowfreq_tewhey_snp_info_train_valid_with_allele_freqs_sig = lowfreq_tewhey_snp_info_train_valid_with_allele_freqs.loc[lowfreq_tewhey_snp_info_train_valid_with_allele_freqs["C.Skew.fdr"]>-np.log10(0.001)]

common_tewhey_snp_info_train_valid_with_allele_freqs_sig = common_tewhey_snp_info_train_valid_with_allele_freqs.loc[common_tewhey_snp_info_train_valid_with_allele_freqs["C.Skew.fdr"]>-np.log10(0.001)]

# %%
rare_tewhey_snp_info_train_valid_with_allele_freqs_sig.shape
# Out:
# (2, 43)

# %%
lowfreq_tewhey_snp_info_train_valid_with_allele_freqs_sig.shape
# Out:
# (47, 43)

# %%
common_tewhey_snp_info_train_valid_with_allele_freqs_sig.shape
# Out:
# (46, 43)

# %%
rare_tewhey_snp_info_train_valid_with_allele_freqs_sig_pos = rare_tewhey_snp_info_train_valid_with_allele_freqs_sig.loc[rare_tewhey_snp_info_train_valid_with_allele_freqs_sig["LogSkew.Comb"]>0]
rare_tewhey_snp_info_train_valid_with_allele_freqs_sig_neg = rare_tewhey_snp_info_train_valid_with_allele_freqs_sig.loc[rare_tewhey_snp_info_train_valid_with_allele_freqs_sig["LogSkew.Comb"]<0]

# %%
lowfreq_tewhey_snp_info_train_valid_with_allele_freqs_sig_pos = lowfreq_tewhey_snp_info_train_valid_with_allele_freqs_sig.loc[lowfreq_tewhey_snp_info_train_valid_with_allele_freqs_sig["LogSkew.Comb"]>0]
lowfreq_tewhey_snp_info_train_valid_with_allele_freqs_sig_neg = lowfreq_tewhey_snp_info_train_valid_with_allele_freqs_sig.loc[lowfreq_tewhey_snp_info_train_valid_with_allele_freqs_sig["LogSkew.Comb"]<0]

# %%
common_tewhey_snp_info_train_valid_with_allele_freqs_sig_pos = common_tewhey_snp_info_train_valid_with_allele_freqs_sig.loc[common_tewhey_snp_info_train_valid_with_allele_freqs_sig["LogSkew.Comb"]>0]
common_tewhey_snp_info_train_valid_with_allele_freqs_sig_neg = common_tewhey_snp_info_train_valid_with_allele_freqs_sig.loc[common_tewhey_snp_info_train_valid_with_allele_freqs_sig["LogSkew.Comb"]<0]

# %%
lowfreq_tewhey_snp_info_train_valid_with_allele_freqs_sig.columns
# Out:
# Index(['ID', 'SNP', 'Direction', 'Haplotype', 'C.A.ctrl.mean', 'C.A.exp.mean',
#        'C.A.log2FC', 'C.A.logP', 'C.A.logPadj', 'C.B.ctrl.mean',
#        'C.B.exp.mean', 'C.B.log2FC', 'C.B.logP', 'C.B.logPadj',
#        'LogSkew.12878', 'LogSkew.19239', 'LogSkew.Comb', 'C.Skew.logP',
#        'C.Skew.fdr', 'tewhey_id', 'chr', '1kg_mapped_id', 'pos', 'hg19_alt',
#        'hg19_ref', 'REF.sequence.1kb', 'ALT.sequence.1kb',
#        'Num.Overlaps.GM.peaks', 'Ref.Dnase.Regression', 'Alt.Dnase.Regression',
#        'Ref.Dnase.Classifier', 'Alt.Dnase.Classifier', 'Ref.MPRA.Regression',
#        'Alt.MPRA.Regression', 'max.allele.logPadj', 'DNase.Regression.Skew',
#        'DNase.Classifier.Skew', 'MPRA.Regression.Skew', 'RSID', 'AFR', 'AMR',
#        'ASN', 'EUR'],
#       dtype='object')

# %%
scatterplot(x="LogSkew.Comb",
            y="DNase.Regression.Skew",
            data=common_tewhey_snp_info_train_valid_with_allele_freqs_sig)
plt.axhline(y=0, c='k', linestyle='--')
plt.axvline(x=0, c='k', linestyle='--')

# %%
scatterplot(x="LogSkew.Comb",
            y="DNase.Classifier.Skew",
            data=common_tewhey_snp_info_train_valid_with_allele_freqs_sig)
plt.axhline(y=0, c='k', linestyle='--')
plt.axvline(x=0, c='k', linestyle='--')

# %%
scatterplot(x="LogSkew.Comb",
            y="DNase.Regression.Skew",
            data=lowfreq_tewhey_snp_info_train_valid_with_allele_freqs_sig)
plt.axhline(y=0, c='k', linestyle='--')
plt.axvline(x=0, c='k', linestyle='--')

# %%
scatterplot(x="LogSkew.Comb",
            y="DNase.Classifier.Skew",
            data=lowfreq_tewhey_snp_info_train_valid_with_allele_freqs_sig)
plt.axhline(y=0, c='k', linestyle='--')
plt.axvline(x=0, c='k', linestyle='--')

# %%
scatterplot(x="DNase.Classifier.Skew",
            y="DNase.Regression.Skew",
            data=lowfreq_tewhey_snp_info_train_valid_with_allele_freqs_sig)
plt.axhline(y=0, c='k', linestyle='--')
plt.axvline(x=0, c='k', linestyle='--')

# %%
scatterplot(x="DNase.Classifier.Skew",
            y="DNase.Regression.Skew",
            data=common_tewhey_snp_info_train_valid_with_allele_freqs_sig)
plt.axhline(y=0, c='k', linestyle='--')
plt.axvline(x=0, c='k', linestyle='--')

# %%
common_tewhey_snp_info_train_valid_with_allele_freqs_sig.loc[common_tewhey_snp_info_train_valid_with_allele_freqs_sig["DNase.Classifier.Skew"]*common_tewhey_snp_info_train_valid_with_allele_freqs_sig["LogSkew.Comb"]>=0].shape
# Out:
# (34, 43)

# %%
common_tewhey_snp_info_train_valid_with_allele_freqs_sig.loc[common_tewhey_snp_info_train_valid_with_allele_freqs_sig["DNase.Classifier.Skew"]*common_tewhey_snp_info_train_valid_with_allele_freqs_sig["LogSkew.Comb"]<0].shape
# Out:
# (12, 43)

# %%
common_tewhey_snp_info_train_valid_with_allele_freqs_sig.loc[common_tewhey_snp_info_train_valid_with_allele_freqs_sig["DNase.Regression.Skew"]*common_tewhey_snp_info_train_valid_with_allele_freqs_sig["LogSkew.Comb"]>=0].shape
# Out:
# (35, 43)

# %%
common_tewhey_snp_info_train_valid_with_allele_freqs_sig.loc[common_tewhey_snp_info_train_valid_with_allele_freqs_sig["DNase.Regression.Skew"]*common_tewhey_snp_info_train_valid_with_allele_freqs_sig["LogSkew.Comb"]<0].shape
# Out:
# (11, 43)

# %%
lowfreq_tewhey_snp_info_train_valid_with_allele_freqs_sig.loc[lowfreq_tewhey_snp_info_train_valid_with_allele_freqs_sig["DNase.Classifier.Skew"]*lowfreq_tewhey_snp_info_train_valid_with_allele_freqs_sig["LogSkew.Comb"]>=0].shape
# Out:
# (35, 43)

# %%
lowfreq_tewhey_snp_info_train_valid_with_allele_freqs_sig.loc[lowfreq_tewhey_snp_info_train_valid_with_allele_freqs_sig["DNase.Classifier.Skew"]*lowfreq_tewhey_snp_info_train_valid_with_allele_freqs_sig["LogSkew.Comb"]<0].shape
# Out:
# (12, 43)

# %%
lowfreq_tewhey_snp_info_train_valid_with_allele_freqs_sig.loc[lowfreq_tewhey_snp_info_train_valid_with_allele_freqs_sig["DNase.Regression.Skew"]*lowfreq_tewhey_snp_info_train_valid_with_allele_freqs_sig["LogSkew.Comb"]>=0].shape
# Out:
# (36, 43)

# %%
lowfreq_tewhey_snp_info_train_valid_with_allele_freqs_sig.loc[lowfreq_tewhey_snp_info_train_valid_with_allele_freqs_sig["DNase.Regression.Skew"]*lowfreq_tewhey_snp_info_train_valid_with_allele_freqs_sig["LogSkew.Comb"]<0].shape
# Out:
# (11, 43)
